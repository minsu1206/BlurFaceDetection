# %% [markdown]
# <a href="https://colab.research.google.com/github/hjhyunjinkim/Blur-Detection-Test/blob/main/ArcFace_iterative_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import output
# !git clone -b blur-type-dataset --single-branch https://github.com/minsu1206/BlurFaceDetection.git
# Out:
# Cloning into 'BlurFaceDetection'...
# remote: Enumerating objects: 259, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 259 (delta 63), reused 140 (delta 61), pack-reused 117
# Receiving objects: 100% (259/259), 38.48 MiB | 42.88 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# Install requirements
# !pip install facenet_pytorch
# !pip install -U Cython cmake numpy
# !pip install onnxruntime
# !pip install -U insightface
output.clear()

# %%
# Make directory to get sample data 
# %cd '/content/BlurFaceDetection/FaceBlurring/data/'
# !mkdir -p 'sample_root/clean/'
# %cd 'sample_root/clean/'
# Out:
# /content/BlurFaceDetection/FaceBlurring/data
# /content/BlurFaceDetection/FaceBlurring/data/sample_root/clean

# %%
# Download sample data and unzip to data directory
# !gdown https://drive.google.com/uc?id=1jonSjJhywVMYHel3u8XNUQH684VyneWf
# !unzip -o sample.zip
# !rm sample.zip
output.clear()

# %% [markdown]
# #Create Degree 25 Samples

# %%
# generate blur data with samples(It takes some time)
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 25}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 4it [00:00, 2377.05it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 81035.60it/s]
# download_path: /root/.insightface/models/buffalo_l
# Downloading /root/.insightface/models/buffalo_l.zip from http://insightface.cn-sh2.ufileos.com/models/buffalo_l.zip...
# 100% 281857/281857 [04:34<00:00, 1026.13KB/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [01:01<00:00,  6.90it/s]

# %% [markdown]
# #Create Degree 50 Samples

# %%
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 50}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 7it [00:00, 2693.10it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 78129.73it/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [01:07<00:00,  6.36it/s]

# %% [markdown]
# #Create Degree 75 Samples

# %%
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 75}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 9it [00:00, 2583.94it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 70663.56it/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [01:03<00:00,  6.70it/s]

# %% [markdown]
# #Create Degree 100 Samples

# %%
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 100}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 11it [00:00, 1519.17it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 70669.13it/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [01:16<00:00,  5.56it/s]

# %% [markdown]
# #Create Degree 200 Samples

# %%
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 200}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 13it [00:00, 2179.56it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 78482.38it/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [02:00<00:00,  3.54it/s]

# %% [markdown]
# #ArcFace Recognition Test with Sample

# %% [markdown]
# <h3>Blur Defocus 25</h3>

# %%
import os
blur_images = os.listdir(r"../data/sample_root/blur_defocus_25/ffhq_samples")
clean_images = os.listdir(r"../data/sample_root/clean/ffhq_samples")

# %%
img1_path = blur_images[45]
img2_path = clean_images[45]
blur_img = os.path.join("../data/sample_root/blur_defocus_25/ffhq_samples", img1_path)
clean_img = os.path.join("../data/sample_root/clean/ffhq_samples", img2_path)

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

im1 = Image.open(blur_img)
plt.imshow(im1)
plt.title("BLURRED IMAGE")
# Out:
# Text(0.5, 1.0, 'BLURRED IMAGE')

# %%
im2 = Image.open(clean_img)
plt.imshow(im2)
plt.title("CLEAN IMAGE")
# Out:
# Text(0.5, 1.0, 'CLEAN IMAGE')

# %%
# !pip install deepface
from deepface import DeepFace
import torch
import numpy as np
output.clear()

# %% [markdown]
# Cosine Similarity<br/>
# L1 Distance<br/>
# L2 Distance

# %%
result1 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="cosine")
print(result1)
result2 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean")
print(result2)
result3 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean_l2")
print(result3)
# Out:
# {'verified': True, 'distance': 0.0397920986041016, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': True, 'distance': 2.2908804837861254, 'threshold': 4.15, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# {'verified': True, 'distance': 0.2821067124479733, 'threshold': 1.13, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}

# %% [markdown]
# <h3>Blur Defocus 50</h3>

# %%
blur_images = os.listdir(r"../data/sample_root/blur_defocus_50/ffhq_samples")
clean_images = os.listdir(r"../data/sample_root/clean/ffhq_samples")

# %%
img1_path = blur_images[45]
img2_path = clean_images[45]
blur_img = os.path.join("../data/sample_root/blur_defocus_50/ffhq_samples", img1_path)
clean_img = os.path.join("../data/sample_root/clean/ffhq_samples", img2_path)

# %%
im1 = Image.open(blur_img)
plt.imshow(im1)
plt.title("BLURRED IMAGE")
# Out:
# Text(0.5, 1.0, 'BLURRED IMAGE')

# %%
im2 = Image.open(clean_img)
plt.imshow(im2)
plt.title("CLEAN IMAGE")
# Out:
# Text(0.5, 1.0, 'CLEAN IMAGE')

# %% [markdown]
# Cosine Similarity<br/>
# L1 Distance<br/>
# L2 Distance

# %%
result1 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="cosine")
print(result1)
result2 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean")
print(result2)
result3 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean_l2")
print(result3)
# Out:
# {'verified': True, 'distance': 0.009566035078535484, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': False, 'distance': 7.405170699107267, 'threshold': 4.15, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# {'verified': True, 'distance': 0.1383187267041999, 'threshold': 1.13, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}

# %% [markdown]
# <h3>Blur Defocus 100</h3>

# %%
blur_images = os.listdir(r"../data/sample_root/blur_defocus_100/ffhq_samples")
clean_images = os.listdir(r"../data/sample_root/clean/ffhq_samples")

# %%
img1_path = blur_images[45]
img2_path = clean_images[45]
blur_img = os.path.join("../data/sample_root/blur_defocus_100/ffhq_samples", img1_path)
clean_img = os.path.join("../data/sample_root/clean/ffhq_samples", img2_path)

# %%
im1 = Image.open(blur_img)
plt.imshow(im1)
plt.title("BLURRED IMAGE")
# Out:
# Text(0.5, 1.0, 'BLURRED IMAGE')

# %%
im2 = Image.open(clean_img)
plt.imshow(im2)
plt.title("CLEAN IMAGE")
# Out:
# Text(0.5, 1.0, 'CLEAN IMAGE')

# %%
result1 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="cosine")
print(result1)
result2 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean")
print(result2)
result3 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean_l2")
print(result3)
# Out:
# {'verified': True, 'distance': 0.012934871327959119, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': False, 'distance': 5.192144367551291, 'threshold': 4.15, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# {'verified': True, 'distance': 0.16084073692916925, 'threshold': 1.13, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}

# %% [markdown]
# <h3>Blur Defocus 75</h3>

# %%
blur_images = os.listdir(r"../data/sample_root/blur_defocus_75/ffhq_samples")
clean_images = os.listdir(r"../data/sample_root/clean/ffhq_samples")

# %%
img1_path = blur_images[45]
img2_path = clean_images[45]
blur_img = os.path.join("../data/sample_root/blur_defocus_75/ffhq_samples", img1_path)
clean_img = os.path.join("../data/sample_root/clean/ffhq_samples", img2_path)

# %%
im1 = Image.open(blur_img)
plt.imshow(im1)
plt.title("BLURRED IMAGE")
# Out:
# Text(0.5, 1.0, 'BLURRED IMAGE')

# %%
im2 = Image.open(clean_img)
plt.imshow(im2)
plt.title("CLEAN IMAGE")
# Out:
# Text(0.5, 1.0, 'CLEAN IMAGE')

# %%
result1 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="cosine")
print(result1)
result2 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean")
print(result2)
result3 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean_l2")
print(result3)
# Out:
# {'verified': True, 'distance': 0.07281521209125807, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': True, 'distance': 3.2344602299425365, 'threshold': 4.15, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# {'verified': True, 'distance': 0.38161554499589806, 'threshold': 1.13, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}

# %% [markdown]
# Due to the discrepancy of the recognition distance metrics, I have added defocus degree 60 and 80

# %%
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 60}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 15it [00:00, 2401.59it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 78654.71it/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [01:07<00:00,  6.28it/s]

# %%
# %cd '/content/BlurFaceDetection/FaceBlurring/dataset/'
# !python create_blurimg.py --blur defocus --save True --label True --hyperparam '{"degree": 80}'
# Out:
# /content/BlurFaceDetection/FaceBlurring/dataset
# Check all sample images(clean)...
# 17it [00:00, 2285.21it/s]
# Create sample directories...
# 100% 427/427 [00:00<00:00, 76127.17it/s]
# /usr/local/lib/python3.7/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:56: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   "Available providers: '{}'".format(name, ", ".join(available_provider_names))
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/genderage.onnx genderage
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition
# set det-size: (640, 640)
# Generate blur images...
# 100% 427/427 [01:08<00:00,  6.24it/s]

# %% [markdown]
# <h3>Blur Defocus 60 Test</h3>

# %%
blur_images = os.listdir(r"../data/sample_root/blur_defocus_60/ffhq_samples")
clean_images = os.listdir(r"../data/sample_root/clean/ffhq_samples")

# %%
img1_path = blur_images[45]
img2_path = clean_images[45]
blur_img = os.path.join("../data/sample_root/blur_defocus_60/ffhq_samples", img1_path)
clean_img = os.path.join("../data/sample_root/clean/ffhq_samples", img2_path)

# %%
im1 = Image.open(blur_img)
plt.imshow(im1)
plt.title("BLURRED IMAGE")
# Out:
# Text(0.5, 1.0, 'BLURRED IMAGE')

# %%
im2 = Image.open(clean_img)
plt.imshow(im2)
plt.title("CLEAN IMAGE")
# Out:
# Text(0.5, 1.0, 'CLEAN IMAGE')

# %%
result1 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="cosine")
print(result1)
result2 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean")
print(result2)
result3 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean_l2")
print(result3)
# Out:
# {'verified': True, 'distance': 0.05841566998203229, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': True, 'distance': 2.7116571587605365, 'threshold': 4.15, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# {'verified': True, 'distance': 0.3418059975542627, 'threshold': 1.13, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}

# %% [markdown]
# <h3>Blur Defocus 80 Test</h3>

# %%
blur_images = os.listdir(r"../data/sample_root/blur_defocus_80/ffhq_samples")
clean_images = os.listdir(r"../data/sample_root/clean/ffhq_samples")

# %%
img1_path = blur_images[45]
img2_path = clean_images[45]
blur_img = os.path.join("../data/sample_root/blur_defocus_80/ffhq_samples", img1_path)
clean_img = os.path.join("../data/sample_root/clean/ffhq_samples", img2_path)

# %%
im1 = Image.open(blur_img)
plt.imshow(im1)
plt.title("BLURRED IMAGE")
# Out:
# Text(0.5, 1.0, 'BLURRED IMAGE')

# %%
im2 = Image.open(clean_img)
plt.imshow(im2)
plt.title("CLEAN IMAGE")
# Out:
# Text(0.5, 1.0, 'CLEAN IMAGE')

# %%
result1 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="cosine")
print(result1)
result2 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean")
print(result2)
result3 = DeepFace.verify(img1_path=blur_img, img2_path=clean_img, model_name="ArcFace", distance_metric="euclidean_l2")
print(result3)
# Out:
# {'verified': True, 'distance': 0.5496288300367504, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# {'verified': False, 'distance': 7.181346985453426, 'threshold': 4.15, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# {'verified': True, 'distance': 1.0484548917685974, 'threshold': 1.13, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}
